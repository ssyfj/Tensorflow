# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np

# %%
#数据载入---有其他方法
mnist = input_data.read_data_sets("MNIST_data",one_hot=True) #注意输出标签是one_hot类型

#按批次进行计算
#设置每个批次大小
batch_size = 10
#获取批次数量，注意：我们训练时使用的是mnist.train训练集数据
n_batch = mnist.train.num_examples // batch_size #注意：//也是除法，返回整数

#开始定义占位符号
x = tf.placeholder(tf.float32,[None,784]) #由于每张图片都是28×28像素，所以每个样本的特征都是784
y = tf.placeholder(tf.float32,[None,10]) #是分10类

#开始创建一个神经网络隐藏层L1含有10个激活单元
Weight_L1 = tf.Variable(tf.random.normal([784,200])) #注意：如果我们将所有权值初始化为0,则神经网络不会进行权重的改变
biases_L1 = tf.Variable(tf.zeros([1,200])) #对于偏执单元的权重，我们没有必要进行随机初始化
Wx_plus_b_L1 = tf.matmul(x,Weight_L1)+biases_L1
L1 = tf.nn.tanh(Wx_plus_b_L1)

#开始创建输出层
Weight_L2 = tf.Variable(tf.random.normal([200,10]))
biases_L2 = tf.Variable(tf.zeros([1,10]))
Wx_plus_b_L2 = tf.matmul(L1,Weight_L2)+biases_L2
y_pred = tf.nn.softmax(Wx_plus_b_L2) #注意：这里我们使用softmax进行分类操作

#定义代价函数
loss = tf.reduce_mean(tf.square(y_pred-y)) #这里没有使用反向传播来求解代价信息
#使用梯度下降法https://www.cnblogs.com/ssyfj/p/12791935.html学习率可以选取0.01,0.03,0.1，0.3,1,3,10...
train_step = tf.train.GradientDescentOptimizer(3).minimize(loss)

init = tf.global_variables_initializer()

#获取结果存放在bool列表中
correct_prediction = tf.equal(tf.arg_max(y,1),tf.arg_max(y_pred,1)) #注意：arg_max第二个参数是指定坐标信息，因为结果按行存储，所以1
#根据上面的bool列表，获取准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32)) #tf.cast格式转换后，求解平均值


#开启会话
with tf.Session() as sess:
    sess.run(init)
    for iter_cnt in range(51): #整体数据迭代
        for batch_cnt in range(n_batch): #小批次数据分批次迭代
            batch_xs,batch_ys = mnist.train.next_batch(batch_size) #依照batch获取下一批次数据
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys}) #传入数据，进行训练
            
        #获取每一次整体数据迭代后的准确率
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels}) #注意：预测时，我们也要传入数据，并且传入的是测试集数据
        print("Iter: %d, Testing accuracy:%f"%(iter_cnt,acc))


#96%左右---增加隐藏层激活单元数（这里是增大了），降低批处理数据集个数（降低了个数），调整学习率（增加了），调整学习次数（增加了）
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Iter: 0, Testing accuracy:0.702800
# Iter: 1, Testing accuracy:0.718200
# Iter: 2, Testing accuracy:0.738800
# Iter: 3, Testing accuracy:0.744600
# Iter: 4, Testing accuracy:0.831300
# Iter: 5, Testing accuracy:0.834300
# Iter: 6, Testing accuracy:0.845700
# Iter: 7, Testing accuracy:0.912000
# Iter: 8, Testing accuracy:0.930500
# Iter: 9, Testing accuracy:0.932400
# Iter: 10, Testing accuracy:0.934600
# Iter: 11, Testing accuracy:0.940000
# Iter: 12, Testing accuracy:0.940100
# Iter: 13, Testing accuracy:0.935900
# Iter: 14, Testing accuracy:0.942000
# Iter: 15, Testing accuracy:0.946600
# Iter: 16, Testing accuracy:0.947700
# Iter: 17, Testing accuracy:0.948000
# Iter: 18, Testing accuracy:0.948800
# Iter: 19, Testing accuracy:0.953400
# Iter: 20, Testing accuracy:0.951900
# Iter: 21, Testing accuracy:0.949700
# Iter: 22, Testing accuracy:0.953100
# Iter: 23, Testing accuracy:0.953800
# Iter: 24, Testing accuracy:0.951700
# Iter: 25, Testing accuracy:0.952900
# Iter: 26, Testing accuracy:0.955300
# Iter: 27, Testing accuracy:0.956800
# Iter: 28, Testing accuracy:0.953400
# Iter: 29, Testing accuracy:0.955800
# Iter: 30, Testing accuracy:0.956700
# Iter: 31, Testing accuracy:0.954900
# Iter: 32, Testing accuracy:0.957700
# Iter: 33, Testing accuracy:0.957200
# Iter: 34, Testing accuracy:0.959000
# Iter: 35, Testing accuracy:0.958900
# Iter: 36, Testing accuracy:0.960500
# Iter: 37, Testing accuracy:0.959300
# Iter: 38, Testing accuracy:0.955700
# Iter: 39, Testing accuracy:0.960800
# Iter: 40, Testing accuracy:0.960100
# Iter: 41, Testing accuracy:0.960100
# Iter: 42, Testing accuracy:0.959300
# Iter: 43, Testing accuracy:0.961800
# Iter: 44, Testing accuracy:0.961700
# Iter: 45, Testing accuracy:0.961400
# Iter: 46, Testing accuracy:0.962400
# Iter: 47, Testing accuracy:0.962800
# Iter: 48, Testing accuracy:0.958700
# Iter: 49, Testing accuracy:0.961100
# Iter: 50, Testing accuracy:0.958100

# %%
#数据载入---有其他方法
mnist = input_data.read_data_sets("MNIST_data",one_hot=True) #注意输出标签是one_hot类型

#按批次进行计算
#设置每个批次大小
batch_size = 100
#获取批次数量，注意：我们训练时使用的是mnist.train训练集数据
n_batch = mnist.train.num_examples // batch_size #注意：//也是除法，返回整数

#开始定义占位符号
x = tf.placeholder(tf.float32,[None,784]) #由于每张图片都是28×28像素，所以每个样本的特征都是784
y = tf.placeholder(tf.float32,[None,10]) #是分10类

#开始创建一个神经网络隐藏层L1含有10个激活单元
Weight_L1 = tf.Variable(tf.zeros([784,10]))
biases_L1 = tf.Variable(tf.zeros([1,10])) #对于偏执单元的权重，我们没有必要进行随机初始化
Wx_plus_b_L1 = tf.matmul(x,Weight_L1)+biases_L1
y_pred = tf.nn.softmax(Wx_plus_b_L1)

#定义代价函数
loss = tf.reduce_mean(tf.square(y_pred-y)) #这里没有使用反向传播来求解代价信息
#使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

init = tf.global_variables_initializer()

#获取结果存放在bool列表中
correct_prediction = tf.equal(tf.arg_max(y,1),tf.arg_max(y_pred,1)) #注意：arg_max第二个参数是指定坐标信息，因为结果按行存储，所以1
#根据上面的bool列表，获取准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32)) #tf.cast格式转换后，求解平均值


#开启会话
with tf.Session() as sess:
    sess.run(init)
    for iter_cnt in range(21): #整体数据迭代
        for batch_cnt in range(n_batch): #小批次数据分批次迭代
            batch_xs,batch_ys = mnist.train.next_batch(batch_size) #依照batch_size获取下一批次数据
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys}) #传入数据，进行训练
            
        #获取每一次整体数据迭代后的准确率
        acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels}) #注意：预测时，我们也要传入数据，并且传入的是测试集数据
        print("Iter: %d, Testing accuracy:%f"%(iter_cnt,acc))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Iter: 0, Testing accuracy:0.828000
# Iter: 1, Testing accuracy:0.871900
# Iter: 2, Testing accuracy:0.882100
# Iter: 3, Testing accuracy:0.888300
# Iter: 4, Testing accuracy:0.893300
# Iter: 5, Testing accuracy:0.897300
# Iter: 6, Testing accuracy:0.899300
# Iter: 7, Testing accuracy:0.901100
# Iter: 8, Testing accuracy:0.903900
# Iter: 9, Testing accuracy:0.905400
# Iter: 10, Testing accuracy:0.906400
# Iter: 11, Testing accuracy:0.907500
# Iter: 12, Testing accuracy:0.908100
# Iter: 13, Testing accuracy:0.909400
# Iter: 14, Testing accuracy:0.909400
# Iter: 15, Testing accuracy:0.911300
# Iter: 16, Testing accuracy:0.911400
# Iter: 17, Testing accuracy:0.911700
# Iter: 18, Testing accuracy:0.913300
# Iter: 19, Testing accuracy:0.913500
# Iter: 20, Testing accuracy:0.914000
